# %% [markdown]
# <a href="https://colab.research.google.com/github/KWERA/Eulers_Loan_Prediction/blob/main/Copy_of_LOAN_CHALLENGE_CHALLENGE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount ('/content/drive')
import pandas as pd
df1 = pd.read_csv("/content/drive/MyDrive/data/traindemographics.csv")
df2 =pd.read_csv("/content/drive/MyDrive/data/trainperf.csv")
df3 =pd.read_csv("/content/drive/MyDrive/data/trainprevloans.csv")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4346 entries, 0 to 4345
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   customerid                  4346 non-null   object
#  1   birthdate                   4346 non-null   object
#  2   bank_account_type           4346 non-null   object
#  3   longitude_gps               4346 non-null   float64
#  4   latitude_gps                4346 non-null   float64
#  5   bank_name_clients           4346 non-null   object
#  6   bank_branch_clients         51 non-null     object
#  7   employment_status_clients   3698 non-null   object
#  8   level_of_education_clients  587 non-null    object
# dtypes: float64(2), object(7)
# memory usage: 305.7+ KB

# %%
df1.head(3)
# Out:
#                          customerid                   birthdate  \
# 0  8a858e135cb22031015cbafc76964ebd  1973-10-10 00:00:00.000000
# 1  8a858e275c7ea5ec015c82482d7c3996  1986-01-21 00:00:00.000000
# 2  8a858e5b5bd99460015bdc95cd485634  1987-04-01 00:00:00.000000
#
#   bank_account_type  longitude_gps  latitude_gps bank_name_clients  \
# 0           Savings       3.319219      6.528604           GT Bank
# 1           Savings       3.325598      7.119403     Sterling Bank
# 2           Savings       5.746100      5.563174     Fidelity Bank
#
#   bank_branch_clients employment_status_clients level_of_education_clients
# 0                 NaN                       NaN                        NaN
# 1                 NaN                 Permanent                        NaN
# 2                 NaN                       NaN                        NaN

# %%
df1.tail(3)
# Out:
#                             customerid                   birthdate  \
# 4343  8a858f4f5b66de3a015b66fc83c61902  1989-09-26 00:00:00.000000
# 4344  8aaae7a74400b28201441c8b62514150  1985-09-06 00:00:00.000000
# 4345  8a85896653e2e18b0153e69c1b90265c  1975-06-05 00:00:00.000000
#
#      bank_account_type  longitude_gps  latitude_gps bank_name_clients  \
# 4343           Savings       6.295530      7.092508           GT Bank
# 4344           Savings       3.354206      6.539070           GT Bank
# 4345           Savings       6.661014      7.472700               UBA
#
#      bank_branch_clients employment_status_clients level_of_education_clients
# 4343                 NaN                 Permanent                        NaN
# 4344         HEAD OFFICE                 Permanent                    Primary
# 4345                 NaN                 Permanent                        NaN

# %%
df1.isnull()
# Out:
#       customerid  birthdate  bank_account_type  longitude_gps  latitude_gps  \
# 0          False      False              False          False         False
# 1          False      False              False          False         False
# 2          False      False              False          False         False
# 3          False      False              False          False         False
# 4          False      False              False          False         False
# ...          ...        ...                ...            ...           ...
# 4341       False      False              False          False         False
# 4342       False      False              False          False         False
# 4343       False      False              False          False         False
# 4344       False      False              False          False         False
# 4345       False      False              False          False         False
#
# ...

# %%
df1.notnull()
# Out:
#       customerid  birthdate  bank_account_type  longitude_gps  latitude_gps  \
# 0           True       True               True           True          True
# 1           True       True               True           True          True
# 2           True       True               True           True          True
# 3           True       True               True           True          True
# 4           True       True               True           True          True
# ...          ...        ...                ...            ...           ...
# 4341        True       True               True           True          True
# 4342        True       True               True           True          True
# 4343        True       True               True           True          True
# 4344        True       True               True           True          True
# 4345        True       True               True           True          True
#
# ...

# %%
df1.head(3)

df1.columns
# Out:
# Index(['customerid', 'birthdate', 'bank_account_type', 'longitude_gps',
#        'latitude_gps', 'bank_name_clients', 'bank_branch_clients',
#        'employment_status_clients', 'level_of_education_clients'],
#       dtype='object')

# %%
df1.isnull().sum()
# Out:
# customerid                       0
# birthdate                        0
# bank_account_type                0
# longitude_gps                    0
# latitude_gps                     0
# bank_name_clients                0
# bank_branch_clients           4295
# employment_status_clients      648
# level_of_education_clients    3759
# dtype: int64

# %%
df1.notnull().sum()
# Out:
# customerid                    4346
# birthdate                     4346
# bank_account_type             4346
# longitude_gps                 4346
# latitude_gps                  4346
# bank_name_clients             4346
# bank_branch_clients             51
# employment_status_clients     3698
# level_of_education_clients     587
# dtype: int64

# %%
df1.head(3)

df1.columns
# Out:
# Index(['customerid', 'birthdate', 'bank_account_type', 'longitude_gps',
#        'latitude_gps', 'bank_name_clients', 'bank_branch_clients',
#        'employment_status_clients', 'level_of_education_clients'],
#       dtype='object')

# %%
df1.dtypes
# Out:
# customerid                     object
# birthdate                      object
# bank_account_type              object
# longitude_gps                 float64
# latitude_gps                  float64
# bank_name_clients              object
# bank_branch_clients            object
# employment_status_clients      object
# level_of_education_clients     object
# dtype: object

# %%
df1.value_counts()
# Out:
# customerid                        birthdate                   bank_account_type  longitude_gps  latitude_gps  bank_name_clients  bank_branch_clients                                             employment_status_clients  level_of_education_clients
# 8a1088a0484472eb01484669e3ce4e0b  1989-11-09 00:00:00.000000  Savings            3.351667       6.657019      GT Bank            OJUELEGBA                                                       Permanent                  Primary                       1
# 8a858f475b8bd761015b8c03cb5920cf  1993-10-26 00:00:00.000000  Savings            3.355625       6.637496      FCMB               AKUTE                                                           Permanent                  Graduate                      1
# ...

# %%
df1.shape
# Out:
# (4346, 9)

# %%
df1['bank_branch_clients'].value_counts()#  can be dropped ,many missing values and not relevant
# Out:
# bank_branch_clients
# OGBA                                                              3
# HEAD OFFICE                                                       2
# AJOSE ADEOGUN                                                     2
# OREGUN                                                            2
# APAPA                                                             2
# AKOWONJO                                                          1
# 47 LAGOS ROAD, IKORODU                                            1
# OAU ILE IFE                                                       1
# RING ROAD                                                         1
# PLOT 999C DANMOLE STREET, ADEOLA ODEKU, VICTORIA ISLAND, LAGOS    1
# HERITAGE BANK, DUGBE, IBADAN                                      1
# ADEOLA HOPEWELL                                                   1
# WHARF ROAD, APAPA                                                 1
# ...

# %%
df1['level_of_education_clients'].value_counts() #can be dropped doesnt seem relevant
# Out:
# level_of_education_clients
# Graduate         420
# Secondary         89
# Post-Graduate     68
# Primary           10
# Name: count, dtype: int64

# %%
df1['employment_status_clients'].value_counts()
# Out:
# employment_status_clients
# Permanent        3146
# Self-Employed     348
# Student           142
# Unemployed         57
# Retired             4
# Contract            1
# Name: count, dtype: int64

# %%
df1['employment_status_clients']=df1['employment_status_clients'].fillna('unknown')

# %%
df1.head()
# Out:
#                          customerid                   birthdate  \
# 0  8a858e135cb22031015cbafc76964ebd  1973-10-10 00:00:00.000000
# 1  8a858e275c7ea5ec015c82482d7c3996  1986-01-21 00:00:00.000000
# 2  8a858e5b5bd99460015bdc95cd485634  1987-04-01 00:00:00.000000
# 3  8a858efd5ca70688015cabd1f1e94b55  1991-07-19 00:00:00.000000
# 4  8a858e785acd3412015acd48f4920d04  1982-11-22 00:00:00.000000
#
#   bank_account_type  longitude_gps  latitude_gps bank_name_clients  \
# 0           Savings       3.319219      6.528604           GT Bank
# 1           Savings       3.325598      7.119403     Sterling Bank
# 2           Savings       5.746100      5.563174     Fidelity Bank
# 3           Savings       3.362850      6.642485           GT Bank
# 4           Savings       8.455332     11.971410           GT Bank
#
#   bank_branch_clients employment_status_clients level_of_education_clients
# 0                 NaN                   unknown                        NaN
# ...

# %% [markdown]
# dropping irrelevant and columns with several null values

# %%
df1.drop("bank_branch_clients",axis=1)
# Out:
#                             customerid                   birthdate  \
# 0     8a858e135cb22031015cbafc76964ebd  1973-10-10 00:00:00.000000
# 1     8a858e275c7ea5ec015c82482d7c3996  1986-01-21 00:00:00.000000
# 2     8a858e5b5bd99460015bdc95cd485634  1987-04-01 00:00:00.000000
# 3     8a858efd5ca70688015cabd1f1e94b55  1991-07-19 00:00:00.000000
# 4     8a858e785acd3412015acd48f4920d04  1982-11-22 00:00:00.000000
# ...                                ...                         ...
# 4341  8a858f155554552501555588ca2b3b40  1985-12-13 00:00:00.000000
# 4342  8a858fc65cf978f4015cf97cee3a02ce  1982-07-01 00:00:00.000000
# 4343  8a858f4f5b66de3a015b66fc83c61902  1989-09-26 00:00:00.000000
# 4344  8aaae7a74400b28201441c8b62514150  1985-09-06 00:00:00.000000
# 4345  8a85896653e2e18b0153e69c1b90265c  1975-06-05 00:00:00.000000
#
#      bank_account_type  longitude_gps  latitude_gps bank_name_clients  \
# 0              Savings       3.319219      6.528604           GT Bank
# ...

# %%
df1.columns
# Out:
# Index(['customerid', 'birthdate', 'bank_account_type', 'longitude_gps',
#        'latitude_gps', 'bank_name_clients', 'bank_branch_clients',
#        'employment_status_clients', 'level_of_education_clients'],
#       dtype='object')

# %%
df1.drop("level_of_education_clients",axis=1)
# Out:
#                             customerid                   birthdate  \
# 0     8a858e135cb22031015cbafc76964ebd  1973-10-10 00:00:00.000000
# 1     8a858e275c7ea5ec015c82482d7c3996  1986-01-21 00:00:00.000000
# 2     8a858e5b5bd99460015bdc95cd485634  1987-04-01 00:00:00.000000
# 3     8a858efd5ca70688015cabd1f1e94b55  1991-07-19 00:00:00.000000
# 4     8a858e785acd3412015acd48f4920d04  1982-11-22 00:00:00.000000
# ...                                ...                         ...
# 4341  8a858f155554552501555588ca2b3b40  1985-12-13 00:00:00.000000
# 4342  8a858fc65cf978f4015cf97cee3a02ce  1982-07-01 00:00:00.000000
# 4343  8a858f4f5b66de3a015b66fc83c61902  1989-09-26 00:00:00.000000
# 4344  8aaae7a74400b28201441c8b62514150  1985-09-06 00:00:00.000000
# 4345  8a85896653e2e18b0153e69c1b90265c  1975-06-05 00:00:00.000000
#
#      bank_account_type  longitude_gps  latitude_gps bank_name_clients  \
# 0              Savings       3.319219      6.528604           GT Bank
# ...

# %% [markdown]
# checking for duplicates

# %%
df1['customerid'].value_counts()
# Out:
# customerid
# 8a858fca5c35df2c015c39ad8695343e    2
# 8a858f9f5679951a01567a5b90644817    2
# 8a858fe65675195a015679452588279c    2
# 8a858e625c8d993a015c938f829f77ee    2
# 8a858f1e5cc4bc81015cc548e1eb5206    2
#                                    ..
# 8a858ff15b5d3f84015b5d6327223863    1
# 8a858fab5bfd307b015bfd4d5b96114d    1
# 8a858f6057e2dba50157ee0cb3c55da4    1
# 8a858fa154daefc00154de1b445805fa    1
# 8a85896653e2e18b0153e69c1b90265c    1
# Name: count, Length: 4334, dtype: int64

# %%
df1[df1['customerid']=='8a858fca5c35df2c015c39ad8695343e']
# Out:
#                            customerid                   birthdate  \
# 138  8a858fca5c35df2c015c39ad8695343e  1980-11-26 00:00:00.000000
# 159  8a858fca5c35df2c015c39ad8695343e  1980-11-26 00:00:00.000000
#
#     bank_account_type  longitude_gps  latitude_gps bank_name_clients  \
# 138           Savings       3.352588      7.211089           GT Bank
# 159           Savings       3.352588      7.211089           GT Bank
#
#     bank_branch_clients employment_status_clients level_of_education_clients
# 138                 NaN                 Permanent                        NaN
# 159                 NaN                 Permanent                        NaN

# %%
df1[df1['customerid']=='8a858f9f5679951a01567a5b90644817']
# Out:
#                             customerid                   birthdate  \
# 3546  8a858f9f5679951a01567a5b90644817  1984-12-17 00:00:00.000000
# 4286  8a858f9f5679951a01567a5b90644817  1984-12-17 00:00:00.000000
#
#      bank_account_type  longitude_gps  latitude_gps bank_name_clients  \
# 3546           Savings       4.196662     12.429509       Access Bank
# 4286           Savings       4.196662     12.429509       Access Bank
#
#      bank_branch_clients employment_status_clients level_of_education_clients
# 3546                 NaN                 Permanent                        NaN
# 4286                 NaN                 Permanent                        NaN

# %%
df1.shape
# Out:
# (4346, 9)

# %%
df1[df1.duplicated(subset=['customerid', 'birthdate', 'bank_account_type', 'longitude_gps',
       'latitude_gps', 'bank_name_clients', 'bank_branch_clients',
       'employment_status_clients', 'level_of_education_clients'], keep=False)]
# Out:
#                             customerid                   birthdate  \
# 138   8a858fca5c35df2c015c39ad8695343e  1980-11-26 00:00:00.000000
# 159   8a858fca5c35df2c015c39ad8695343e  1980-11-26 00:00:00.000000
# 272   8a858edd57f790040157ffe9b6ed3fbb  1988-01-18 00:00:00.000000
# 445   8a858e6c5c88d145015c8b9627cd5a48  1979-09-30 00:00:00.000000
# 517   8a858edd57f790040157ffe9b6ed3fbb  1988-01-18 00:00:00.000000
# 750   8a858f965bb63a25015bbf63fd062e2e  1974-02-25 00:00:00.000000
# 776   8a858f965bb63a25015bbf63fd062e2e  1974-02-25 00:00:00.000000
# 798   8a858fc75cd62882015cdaf2f4311b3f  1975-10-27 00:00:00.000000
# 1010  8a858fe65675195a015679452588279c  1982-08-01 00:00:00.000000
# 1015  8a858fe65675195a015679452588279c  1982-08-01 00:00:00.000000
# 1090  8a858e6c5c88d145015c8b9627cd5a48  1979-09-30 00:00:00.000000
# 1188  8a858fc75cd62882015cdaf2f4311b3f  1975-10-27 00:00:00.000000
# 1338  8a858fe05d421ff4015d4c87d2a21ceb  1983-01-20 00:00:00.000000
# ...

# %%
df1=df1.drop_duplicates()

# %%
df1.shape
# Out:
# (4334, 9)

# %% [markdown]
#  Merging longitude_gaps & latitude_gaps

# %%
df1.describe()
# Out:
#        longitude_gps  latitude_gps
# count    4334.000000   4334.000000
# mean        4.624000      7.249975
# std         7.194031      3.056594
# min      -118.247009    -33.868818
# 25%         3.354857      6.470610
# 50%         3.591668      6.621730
# 75%         6.543691      7.425021
# max       151.209290     71.228069

# %%
df1['location']=df1['longitude_gps'].astype('str')+df1['latitude_gps'].astype('str')
# Out:
# <ipython-input-87-960299e3db6a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['location']=df1['longitude_gps'].astype('str')+df1['latitude_gps'].astype('str')

# %%
df1['location'].value_counts()
# Out:
# location
# 3.41797716.4411578    6
# 3.4166.4351           3
# 3.26637816.5212905    2
# 3.85900877.3511715    2
# 6.33316934.9476346    2
#                      ..
# 7.0086754.7802117     1
# 3.26994836.5467152    1
# 7.01204544.8756519    1
# 8.53554412.0036084    1
# 6.6610147.4726999     1
# Name: count, Length: 4314, dtype: int64

# %%
df1.columns
# Out:
# Index(['customerid', 'birthdate', 'bank_account_type', 'longitude_gps',
#        'latitude_gps', 'bank_name_clients', 'bank_branch_clients',
#        'employment_status_clients', 'level_of_education_clients', 'location'],
#       dtype='object')

# %%
df1.head()
# Out:
#                          customerid                   birthdate  \
# 0  8a858e135cb22031015cbafc76964ebd  1973-10-10 00:00:00.000000
# 1  8a858e275c7ea5ec015c82482d7c3996  1986-01-21 00:00:00.000000
# 2  8a858e5b5bd99460015bdc95cd485634  1987-04-01 00:00:00.000000
# 3  8a858efd5ca70688015cabd1f1e94b55  1991-07-19 00:00:00.000000
# 4  8a858e785acd3412015acd48f4920d04  1982-11-22 00:00:00.000000
#
#   bank_account_type  longitude_gps  latitude_gps bank_name_clients  \
# 0           Savings       3.319219      6.528604           GT Bank
# 1           Savings       3.325598      7.119403     Sterling Bank
# 2           Savings       5.746100      5.563174     Fidelity Bank
# 3           Savings       3.362850      6.642485           GT Bank
# 4           Savings       8.455332     11.971410           GT Bank
#
#   bank_branch_clients employment_status_clients level_of_education_clients  \
# 0                 NaN                   unknown                        NaN
# ...

# %%
df1[df1['location']=='3.4166.4351']
# Out:
#                             customerid                   birthdate  \
# 368   8a858f0056b7cf8e0156b9bfbb2066fd  1977-02-11 00:00:00.000000
# 757   8a858f475c7ea023015c7f44743f1d04  1992-10-13 00:00:00.000000
# 1156  8a858fda56562f8f01565f8c6f936c46  1992-08-13 00:00:00.000000
#
#      bank_account_type  longitude_gps  latitude_gps bank_name_clients  \
# 368              Other          3.416        6.4351           GT Bank
# 757            Savings          3.416        6.4351       Access Bank
# 1156             Other          3.416        6.4351           GT Bank
#
#      bank_branch_clients employment_status_clients level_of_education_clients  \
# 368                  NaN                 Permanent              Post-Graduate
# 757                  NaN                 Permanent                        NaN
# 1156                 NaN             Self-Employed                        NaN
#
#          location
# 368   3.4166.4351
# 757   3.4166.4351
# 1156  3.4166.4351

# %%
df1[df1['location']=='3.26637816.5212905']
# Out:
#                             customerid                   birthdate  \
# 513   8a858f6b570f2de901571b4734224a15  1985-12-28 00:00:00.000000
# 2452  8a858edb5a70bfe0015a74c641dc0122  1961-10-13 00:00:00.000000
#
#      bank_account_type  longitude_gps  latitude_gps bank_name_clients  \
# 513              Other       3.266378      6.521291       Access Bank
# 2452           Savings       3.266378      6.521291     Sterling Bank
#
#      bank_branch_clients employment_status_clients level_of_education_clients  \
# 513                  NaN                 Permanent                        NaN
# 2452                 NaN                   unknown                        NaN
#
#                 location
# 513   3.26637816.5212905
# 2452  3.26637816.5212905

# %%
df1[df1['location']=='8.455331711.97141']
# Out:
#                          customerid                   birthdate  \
# 4  8a858e785acd3412015acd48f4920d04  1982-11-22 00:00:00.000000
#
#   bank_account_type  longitude_gps  latitude_gps bank_name_clients  \
# 4           Savings       8.455332      11.97141           GT Bank
#
#   bank_branch_clients employment_status_clients level_of_education_clients  \
# 4                 NaN                 Permanent                        NaN
#
#             location
# 4  8.455331711.97141

# %%
df1.columns
# Out:
# Index(['customerid', 'birthdate', 'bank_account_type', 'longitude_gps',
#        'latitude_gps', 'bank_name_clients', 'bank_branch_clients',
#        'employment_status_clients', 'level_of_education_clients', 'location'],
#       dtype='object')

# %%
df1.shape
# Out:
# (4334, 10)

# %% [markdown]
# DF2 EXPLORATION.

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4368 entries, 0 to 4367
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerid     4368 non-null   object
#  1   systemloanid   4368 non-null   int64
#  2   loannumber     4368 non-null   int64
#  3   approveddate   4368 non-null   object
#  4   creationdate   4368 non-null   object
#  5   loanamount     4368 non-null   float64
#  6   totaldue       4368 non-null   float64
#  7   termdays       4368 non-null   int64
#  8   referredby     587 non-null    object
#  9   good_bad_flag  4368 non-null   object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 341.4+ KB

# %%
df2.head()
# Out:
#                          customerid  systemloanid  loannumber  \
# 0  8a2a81a74ce8c05d014cfb32a0da1049     301994762          12
# 1  8a85886e54beabf90154c0a29ae757c0     301965204           2
# 2  8a8588f35438fe12015444567666018e     301966580           7
# 3  8a85890754145ace015429211b513e16     301999343           3
# 4  8a858970548359cc0154883481981866     301962360           9
#
#                  approveddate                creationdate  loanamount  \
# 0  2017-07-25 08:22:56.000000  2017-07-25 07:22:47.000000     30000.0
# 1  2017-07-05 17:04:41.000000  2017-07-05 16:04:18.000000     15000.0
# 2  2017-07-06 14:52:57.000000  2017-07-06 13:52:51.000000     20000.0
# 3  2017-07-27 19:00:41.000000  2017-07-27 18:00:35.000000     10000.0
# 4  2017-07-03 23:42:45.000000  2017-07-03 22:42:39.000000     40000.0
#
#    totaldue  termdays referredby good_bad_flag
# 0   34500.0        30        NaN          Good
# 1   17250.0        30        NaN          Good
# ...

# %%
df2.shape
# Out:
# (4368, 10)

# %%
df2.isnull()
# Out:
#       customerid  systemloanid  loannumber  approveddate  creationdate  \
# 0          False         False       False         False         False
# 1          False         False       False         False         False
# 2          False         False       False         False         False
# 3          False         False       False         False         False
# 4          False         False       False         False         False
# ...          ...           ...         ...           ...           ...
# 4363       False         False       False         False         False
# 4364       False         False       False         False         False
# 4365       False         False       False         False         False
# 4366       False         False       False         False         False
# 4367       False         False       False         False         False
#
#       loanamount  totaldue  termdays  referredby  good_bad_flag
# ...

# %%
df2.columns
# Out:
# Index(['customerid', 'systemloanid', 'loannumber', 'approveddate',
#        'creationdate', 'loanamount', 'totaldue', 'termdays', 'referredby',
#        'good_bad_flag'],
#       dtype='object')

# %%
df2.describe()
# Out:
#        systemloanid   loannumber    loanamount      totaldue     termdays
# count  4.368000e+03  4368.000000   4368.000000   4368.000000  4368.000000
# mean   3.019810e+08     5.172390  17809.065934  21257.377679    29.261676
# std    1.343115e+04     3.653569  10749.694571  11943.510416    11.512519
# min    3.019585e+08     2.000000  10000.000000  10000.000000    15.000000
# 25%    3.019691e+08     2.000000  10000.000000  13000.000000    30.000000
# 50%    3.019801e+08     4.000000  10000.000000  13000.000000    30.000000
# 75%    3.019935e+08     7.000000  20000.000000  24500.000000    30.000000
# max    3.020040e+08    27.000000  60000.000000  68100.000000    90.000000

# %%
df2.columns
# Out:
# Index(['customerid', 'systemloanid', 'loannumber', 'approveddate',
#        'creationdate', 'loanamount', 'totaldue', 'termdays', 'referredby',
#        'good_bad_flag'],
#       dtype='object')

# %%
df2["systemloanid"].value_counts()
# Out:
# systemloanid
# 301994762    1
# 301970392    1
# 302003414    1
# 301999826    1
# 301972590    1
#             ..
# 301959319    1
# 301960124    1
# 301993159    1
# 301974283    1
# 301967124    1
# Name: count, Length: 4368, dtype: int64

# %%
df2["customerid"].value_counts()
# Out:
# customerid
# 8a2a81a74ce8c05d014cfb32a0da1049    1
# 8a858e6c5c88d145015c894de5001cce    1
# 8a858eaf5b617c94015b61aa95c124b3    1
# 8a858ea55b58f026015b5c07521824eb    1
# 8a858e94580afa79015829ebf4d974d1    1
#                                    ..
# 8a858f385b34d285015b352600354046    1
# 8a858f415686c0ab015691ea91d45900    1
# 8a858f54589736f40158a6bcd6ac24fb    1
# 8a858f5c5ad7d927015adb8b97f96be0    1
# 8a858fd458639fcc015868eb14b542ad    1
# Name: count, Length: 4368, dtype: int64

# %%
df2["loannumber"].value_counts()
# Out:
# loannumber
# 2     1393
# 3      670
# 4      443
# 5      326
# 7      252
# 6      247
# 8      220
# 10     191
# 9      180
# 11     113
# 12     109
# 13      78
# 14      50
# 15      42
# 16      20
# 17      15
# 19       6
# 22       5
# 18       3
# 20       2
# 27       1
# 21       1
# 23       1
# Name: count, dtype: int64

# %%
df2[df2['loannumber']=='14']
# Out:
# Empty DataFrame
# Columns: [customerid, systemloanid, loannumber, approveddate, creationdate, loanamount, totaldue, termdays, referredby, good_bad_flag]
# Index: []

# %%
df2["systemloanid"].value_counts()
# Out:
# systemloanid
# 301994762    1
# 301970392    1
# 302003414    1
# 301999826    1
# 301972590    1
#             ..
# 301959319    1
# 301960124    1
# 301993159    1
# 301974283    1
# 301967124    1
# Name: count, Length: 4368, dtype: int64

# %%
df2[df2.duplicated(subset=['customerid', 'systemloanid', 'loannumber', 'approveddate',
       'creationdate', 'loanamount', 'totaldue', 'termdays', 'referredby',
       'good_bad_flag'], keep=False)]
# Out:
# Empty DataFrame
# Columns: [customerid, systemloanid, loannumber, approveddate, creationdate, loanamount, totaldue, termdays, referredby, good_bad_flag]
# Index: []

# %%
df2["referredby"].value_counts()
# Out:
# referredby
# 8a858fc55b2548dd015b286e452c678c    8
# 8a858eeb5bb559d3015bb57fa13f10de    3
# 8a858f965bb63a25015bc2ddf2577416    3
# 8a858e125b391784015b395fa56243e6    3
# 8a858e335b806e4d015b807c181d101f    2
#                                    ..
# 8a858fd35b5dfefb015b5f002aa050a3    1
# 8a858e3d5c3b5122015c43f776bd4a3a    1
# 8a858f7a5b39a003015b39ca67ab2efb    1
# 8a858fa359d61dae0159d698bf503d29    1
# 8a858eda5c8863ff015c9dead65807bb    1
# Name: count, Length: 521, dtype: int64

# %%
df2.isnull().sum()
# Out:
# customerid          0
# systemloanid        0
# loannumber          0
# approveddate        0
# creationdate        0
# loanamount          0
# totaldue            0
# termdays            0
# referredby       3781
# good_bad_flag       0
# dtype: int64

# %%
df2.drop('referredby', axis=1)#has many null values
# Out:
#                             customerid  systemloanid  loannumber  \
# 0     8a2a81a74ce8c05d014cfb32a0da1049     301994762          12
# 1     8a85886e54beabf90154c0a29ae757c0     301965204           2
# 2     8a8588f35438fe12015444567666018e     301966580           7
# 3     8a85890754145ace015429211b513e16     301999343           3
# 4     8a858970548359cc0154883481981866     301962360           9
# ...                                ...           ...         ...
# 4363  8a858e6d58b0cc520158beeb14b22a5a     302003163           2
# 4364  8a858ee85cf400f5015cf44ab1c42d5c     301998967           2
# 4365  8a858f365b2547f3015b284597147c94     301995576           3
# 4366  8a858f935ca09667015ca0ee3bc63f51     301977679           2
# 4367  8a858fd458639fcc015868eb14b542ad     301967124           8
#
#                     approveddate                creationdate  loanamount  \
# 0     2017-07-25 08:22:56.000000  2017-07-25 07:22:47.000000     30000.0
# ...

# %%
df2.columns
# Out:
# Index(['customerid', 'systemloanid', 'loannumber', 'approveddate',
#        'creationdate', 'loanamount', 'totaldue', 'termdays', 'referredby',
#        'good_bad_flag'],
#       dtype='object')

# %%
df2["termdays"].value_counts()
# Out:
# termdays
# 30    3129
# 15     919
# 60     288
# 90      32
# Name: count, dtype: int64

# %% [markdown]
# Exploration for df3

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18183 entries, 0 to 18182
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   customerid       18183 non-null  object
#  1   systemloanid     18183 non-null  int64
#  2   loannumber       18183 non-null  int64
#  3   approveddate     18183 non-null  object
#  4   creationdate     18183 non-null  object
#  5   loanamount       18183 non-null  float64
#  6   totaldue         18183 non-null  float64
#  7   termdays         18183 non-null  int64
#  8   closeddate       18183 non-null  object
#  9   referredby       1026 non-null   object
#  10  firstduedate     18183 non-null  object
#  11  firstrepaiddate  18183 non-null  object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 1.7+ MB

# %%
df3.shape
df3.columns
# Out:
# Index(['customerid', 'systemloanid', 'loannumber', 'approveddate',
#        'creationdate', 'loanamount', 'totaldue', 'termdays', 'closeddate',
#        'referredby', 'firstduedate', 'firstrepaiddate'],
#       dtype='object')

# %%
df3.shape
# Out:
# (18183, 12)

# %%
df3.head(3)
# Out:
#                          customerid  systemloanid  loannumber  \
# 0  8a2a81a74ce8c05d014cfb32a0da1049     301682320           2
# 1  8a2a81a74ce8c05d014cfb32a0da1049     301883808           9
# 2  8a2a81a74ce8c05d014cfb32a0da1049     301831714           8
#
#                  approveddate                creationdate  loanamount  \
# 0  2016-08-15 18:22:40.000000  2016-08-15 17:22:32.000000     10000.0
# 1  2017-04-28 18:39:07.000000  2017-04-28 17:38:53.000000     10000.0
# 2  2017-03-05 10:56:25.000000  2017-03-05 09:56:19.000000     20000.0
#
#    totaldue  termdays                  closeddate referredby  \
# 0   13000.0        30  2016-09-01 16:06:48.000000        NaN
# 1   13000.0        30  2017-05-28 14:44:49.000000        NaN
# 2   23800.0        30  2017-04-26 22:18:56.000000        NaN
#
#                  firstduedate             firstrepaiddate
# 0  2016-09-14 00:00:00.000000  2016-09-01 15:51:43.000000
# 1  2017-05-30 00:00:00.000000  2017-05-26 00:00:00.000000
# ...

# %%
df3.tail(3)
# Out:
#                              customerid  systemloanid  loannumber  \
# 18180  8a858899538ddb8e0153a2b555421fc5     301631653           4
# 18181  8a858f0656b7820c0156c92ca3ba436f     301697691           1
# 18182  8a858faf5679a838015688de3028143d     301715255           2
#
#                      approveddate                creationdate  loanamount  \
# 18180  2016-06-12 15:30:56.000000  2016-06-12 14:30:50.000000     10000.0
# 18181  2016-08-27 20:03:45.000000  2016-08-27 19:03:34.000000     10000.0
# 18182  2016-09-14 23:42:14.000000  2016-09-14 22:42:05.000000     10000.0
#
#        totaldue  termdays                  closeddate referredby  \
# 18180   13000.0        30  2016-07-09 15:39:00.000000        NaN
# 18181   13000.0        30  2016-10-15 10:17:54.000000        NaN
# 18182   13000.0        30  2016-09-29 19:51:04.000000        NaN
#
#                      firstduedate             firstrepaiddate
# 18180  2016-07-12 00:00:00.000000  2016-07-09 15:23:56.000000
# ...

# %%
df3.describe().T
# Out:
#                 count          mean           std          min          25%  \
# systemloanid  18183.0  3.018395e+08  93677.672704  301600134.0  301776577.0
# loannumber    18183.0  4.189353e+00      3.249490          1.0          2.0
# loanamount    18183.0  1.650124e+04   9320.547516       3000.0      10000.0
# totaldue      18183.0  1.957320e+04  10454.245277       3450.0      11500.0
# termdays      18183.0  2.669279e+01     10.946556         15.0         15.0
#
#                       50%          75%          max
# systemloanid  301854965.0  301919682.5  302000275.0
# loannumber            3.0          6.0         26.0
# loanamount        10000.0      20000.0      60000.0
# totaldue          13000.0      24500.0      68100.0
# termdays             30.0         30.0         90.0

# %%
df3.isnull().sum()
# Out:
# customerid             0
# systemloanid           0
# loannumber             0
# approveddate           0
# creationdate           0
# loanamount             0
# totaldue               0
# termdays               0
# closeddate             0
# referredby         17157
# firstduedate           0
# firstrepaiddate        0
# dtype: int64

# %%
df3['referredby'].value_counts()
# Out:
# referredby
# 8a858fc55b2548dd015b286e452c678c    14
# 8a858f965bb63a25015bc2ddf2577416     9
# 8a858ebb5adce699015adea5d5ae51b3     9
# 8a8589f35451855401547fc55caa6cd5     8
# 8a858e025ab3a6c2015ab74cfa5c4431     7
#                                     ..
# 8a858fb959976ce0015998f0a628583b     1
# 8a858ee65be8d42d015be94e806334fe     1
# 8a858f5e5cb23c77015cc061b752625b     1
# 8a858fea5b391cd7015b393aed9e2a04     1
# 8a858eaa55a0b8ae0155ad2cab5e49cc     1
# Name: count, Length: 521, dtype: int64

# %%
df3[df3 ['referredby']=='8a8589f35451855401547fc55caa6cd5']
# Out:
#                              customerid  systemloanid  loannumber  \
# 605    8a858f615b910db3015b9f5182bb5df7     301924615           3
# 2180   8a858e285ba4bf33015ba50277171d93     301879970           1
# 2508   8a858e285ba4bf33015ba50277171d93     301924118           3
# 2675   8a858f615b910db3015b9f5182bb5df7     301899494           2
# 9362   8a858f615b910db3015b9f5182bb5df7     301878362           1
# 9640   8a858e285ba4bf33015ba50277171d93     301931492           4
# 11703  8a858f615b910db3015b9f5182bb5df7     301931041           4
# 11774  8a858e285ba4bf33015ba50277171d93     301888291           2
#
#                      approveddate                creationdate  loanamount  \
# 605    2017-06-02 09:01:30.000000  2017-06-02 08:01:23.000000     10000.0
# 2180   2017-04-25 13:37:28.000000  2017-04-25 12:37:05.000000     10000.0
# 2508   2017-06-01 16:27:52.000000  2017-06-01 15:27:45.000000     10000.0
# 2675   2017-05-10 15:02:32.000000  2017-05-10 14:02:26.000000     10000.0
# ...

# %%
df3=df3.drop('referredby',axis=1)#dropped column

# %%
df3.shape
# Out:
# (18183, 11)

# %%
df3['customerid'].value_counts()
# Out:
# customerid
# 8a858f7d5578012a01557ea194d94948    26
# 8a858e4456ced8470156d73452f85335    22
# 8a858899538ddb8e0153a780c56e34bb    21
# 8a85886f54517ee0015470749d3c3ce7    21
# 8a858fe5569398920156a3a9a77b5d02    21
#                                     ..
# 8a858f7e5c69a6e3015c779b5d6c03b8     1
# 8a858e165cf9d8e3015d072f06823b83     1
# 8a858e655b903189015b903875da03da     1
# 8a858f025bd49f21015bd8590bd83fe8     1
# 8a858f0656b7820c0156c92ca3ba436f     1
# Name: count, Length: 4359, dtype: int64

# %%
df3[df3['customerid']=='8a858899538ddb8e0153a780c56e34bb']
# Out:
#                              customerid  systemloanid  loannumber  \
# 3465   8a858899538ddb8e0153a780c56e34bb     301666551           8
# 3466   8a858899538ddb8e0153a780c56e34bb     301769218          15
# 3467   8a858899538ddb8e0153a780c56e34bb     301751520          13
# 3468   8a858899538ddb8e0153a780c56e34bb     301621486           4
# 3469   8a858899538ddb8e0153a780c56e34bb     301894834          20
# 3470   8a858899538ddb8e0153a780c56e34bb     301614376           3
# 3958   8a858899538ddb8e0153a780c56e34bb     301701644          10
# 3959   8a858899538ddb8e0153a780c56e34bb     301928711          21
# 3960   8a858899538ddb8e0153a780c56e34bb     301648904           7
# 3961   8a858899538ddb8e0153a780c56e34bb     301791008          16
# 3962   8a858899538ddb8e0153a780c56e34bb     301603964           1
# 11804  8a858899538ddb8e0153a780c56e34bb     301834654          18
# 11805  8a858899538ddb8e0153a780c56e34bb     301811789          17
# ...

# %%
df3=df3.drop('customerid',axis=1)

# %%
df3.shape
# Out:
# (18183, 10)

# %%
df3['systemloanid'].value_counts()
# Out:
# systemloanid
# 301682320    1
# 301754669    1
# 301884544    1
# 301829670    1
# 301923724    1
#             ..
# 301607463    1
# 301836166    1
# 301609879    1
# 301899120    1
# 301715255    1
# Name: count, Length: 18183, dtype: int64

# %%
df3['loannumber'].value_counts()
# Out:
# loannumber
# 1     4344
# 2     2969
# 3     2300
# 4     1860
# 5     1535
# 6     1288
# 7     1036
# 8      817
# 9      637
# 10     446
# 11     333
# 12     223
# 13     146
# 14      96
# 15      54
# 16      33
# 17      19
# 18      16
# 19      10
# 20       8
# 21       7
# 22       2
# 24       1
# 23       1
# 25       1
# 26       1
# Name: count, dtype: int64

# %%
df3['approveddate'].value_counts()
# Out:
# approveddate
# 2017-04-20 14:00:44.000000    2
# 2016-06-07 22:49:34.000000    2
# 2017-06-18 17:01:41.000000    2
# 2016-10-28 13:00:44.000000    2
# 2017-06-10 15:41:37.000000    2
#                              ..
# 2016-05-19 10:12:46.000000    1
# 2016-04-04 13:20:16.000000    1
# 2017-03-11 19:06:14.000000    1
# 2016-04-11 10:37:17.000000    1
# 2016-09-14 23:42:14.000000    1
# Name: count, Length: 18172, dtype: int64

# %%
df3['creationdate'].value_counts()
# Out:
# creationdate
# 2017-06-12 10:38:36.000000    2
# 2017-01-16 15:59:00.000000    2
# 2017-06-05 08:47:53.000000    2
# 2017-06-14 06:13:21.000000    2
# 2017-05-15 08:38:25.000000    2
#                              ..
# 2016-04-11 09:37:11.000000    1
# 2017-05-10 10:54:39.000000    1
# 2017-06-20 20:40:20.000000    1
# 2017-03-13 13:20:27.000000    1
# 2016-09-14 22:42:05.000000    1
# Name: count, Length: 18173, dtype: int64

# %%
df3['loanamount'].value_counts()
# Out:
# loanamount
# 10000.0    10529
# 20000.0     3524
# 30000.0     2452
# 40000.0      867
# 15000.0      394
# 50000.0      106
# 25000.0      100
# 5000.0        95
# 8000.0        38
# 35000.0       27
# 6000.0        19
# 7000.0        11
# 9000.0         9
# 4000.0         5
# 60000.0        5
# 3000.0         2
# Name: count, dtype: int64

# %%
df3['totaldue'].value_counts()
# Out:
# totaldue
# 13000.0    5648
# 11500.0    4291
# 24500.0    1145
# 23800.0    1049
# 34400.0     893
#            ...
# 18050.0       1
# 5200.0        1
# 3900.0        1
# 26250.0       1
# 10000.0       1
# Name: count, Length: 97, dtype: int64

# %%
df3['termdays'].value_counts()
# Out:
# termdays
# 30    11045
# 15     6115
# 60      993
# 90       30
# Name: count, dtype: int64

# %%
df3['closeddate'].value_counts()
# Out:
# closeddate
# 2016-11-07 00:53:42.000000    5
# 2016-04-30 00:02:48.000000    4
# 2017-03-06 01:04:51.000000    4
# 2017-03-24 01:01:28.000000    4
# 2016-04-28 00:04:06.000000    4
#                              ..
# 2016-08-05 11:49:40.000000    1
# 2017-02-09 19:24:03.000000    1
# 2017-07-07 15:39:30.000000    1
# 2017-03-31 09:46:45.000000    1
# 2016-09-29 19:51:04.000000    1
# Name: count, Length: 17955, dtype: int64

# %%
df3['firstduedate'].value_counts()
# Out:
# firstduedate
# 2017-07-03 00:00:00.000000    398
# 2017-07-10 00:00:00.000000    387
# 2017-05-30 00:00:00.000000    319
# 2017-07-24 00:00:00.000000    317
# 2017-06-05 00:00:00.000000    298
#                              ...
# 2016-05-17 00:00:00.000000      1
# 2016-03-03 00:00:00.000000      1
# 2016-02-15 00:00:00.000000      1
# 2016-04-05 00:00:00.000000      1
# 2016-03-02 00:00:00.000000      1
# Name: count, Length: 363, dtype: int64

# %%
df3['firstrepaiddate'].value_counts()
# Out:
# firstrepaiddate
# 2016-08-04 00:00:00.000000    7
# 2016-09-06 00:00:00.000000    7
# 2016-08-03 00:00:00.000000    7
# 2017-05-31 00:00:00.000000    6
# 2016-09-14 00:00:00.000000    5
#                              ..
# 2017-03-07 13:54:53.000000    1
# 2016-12-23 13:14:37.000000    1
# 2017-06-09 15:09:25.000000    1
# 2016-11-21 10:04:53.000000    1
# 2016-09-29 19:35:55.000000    1
# Name: count, Length: 18011, dtype: int64

# %%
df3.columns
# Out:
# Index(['systemloanid', 'loannumber', 'approveddate', 'creationdate',
#        'loanamount', 'totaldue', 'termdays', 'closeddate', 'firstduedate',
#        'firstrepaiddate'],
#       dtype='object')
